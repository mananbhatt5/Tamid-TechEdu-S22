# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/joshleeman/src/Tamid-TechEdu-S22/Week4/data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.describe()
# Out:
#               views         likes
# count  5.440000e+03  5.440000e+03
# mean   2.061576e+06  6.260762e+04
# std    3.567098e+06  1.076468e+05
# min    5.320000e+02  1.500000e+01
# 25%    6.707500e+05  2.000000e+04
# 50%    1.300000e+06  4.050000e+04
# 75%    2.100000e+06  6.500000e+04
# max    7.200000e+07  2.100000e+06

# %%
df2 = df[['author', 'date', 'views', 'likes']]
df2
# Out:
#                     author            date     views    likes
# 0     Ozawa Bineshi Albert   December 2021    404000    12000
# 1            Sydney Iaukea   February 2022    214000     6400
# 2            Martin Reeves  September 2021    412000    12000
# 3        James K. Thornton    October 2021    427000    12000
# 4          Mahendra Singhi    October 2021      2400       72
# ...                    ...             ...       ...      ...
# 5435          Hans Rosling   February 2006  15000000   458000
# 5436      Sir Ken Robinson   February 2006  72000000  2100000
# 5437         Majora Carter   February 2006   2900000    88000
# 5438           David Pogue   February 2006   2000000    60000
# 5439               Al Gore   February 2006   3600000   109000
#
# [5440 rows x 4 columns]

# %%
df3 = df2.loc[df2['date'].str.contains('2021')]
df3
# Out:
#                          author            date    views  likes
# 0          Ozawa Bineshi Albert   December 2021   404000  12000
# 2                 Martin Reeves  September 2021   412000  12000
# 3             James K. Thornton    October 2021   427000  12000
# 4               Mahendra Singhi    October 2021     2400     72
# 5    Rosamund Adoo-Kissi-Debrah    October 2021   422000  12000
# ..                          ...             ...      ...    ...
# 493            Wendy De La Rosa    January 2021   462000  13000
# 496              Robert Siddall    January 2021  1600000  48000
# 500         Soraya Field Fiorio    January 2021   773000  23000
# 504                    Yen Pham    January 2021   484000  14000
# 506                 A.J. Jacobs    January 2021  1100000  34000
#
# [390 rows x 4 columns]

# %%
df4 = df3.loc[df3['likes'] > 1000]
df4
# Out:
#                          author            date    views  likes
# 0          Ozawa Bineshi Albert   December 2021   404000  12000
# 2                 Martin Reeves  September 2021   412000  12000
# 3             James K. Thornton    October 2021   427000  12000
# 5    Rosamund Adoo-Kissi-Debrah    October 2021   422000  12000
# 7              Gay Gordon-Byrne     August 2021   455000  13000
# ..                          ...             ...      ...    ...
# 493            Wendy De La Rosa    January 2021   462000  13000
# 496              Robert Siddall    January 2021  1600000  48000
# 500         Soraya Field Fiorio    January 2021   773000  23000
# 504                    Yen Pham    January 2021   484000  14000
# 506                 A.J. Jacobs    January 2021  1100000  34000
#
# [370 rows x 4 columns]

# %%
df5 = df4.loc[df4['date'].str.contains('October')] 
df5
# Out:
#                                                author          date    views  \
# 3                                   James K. Thornton  October 2021   427000
# 5                          Rosamund Adoo-Kissi-Debrah  October 2021   422000
# 13                                        Lucas Joppa  October 2021   526000
# 17                                        Susan Ruffo  October 2021   522000
# 23                                      Dan Jørgensen  October 2021   632000
# 29                                        Rachel Kyte  October 2021   613000
# 41                                   Gabrielle Walker  October 2021   732000
# 53                                Bjørn Otto Sverdrup  October 2021   825000
# 60                                      Sophia Kianni  October 2021   861000
# 73                                 Jim Hagemann Snabe  October 2021   837000
# 79                                Vishaan Chakrabarti  October 2021  1000000
# ...

# %%
df5.to_csv('ted_talk_data.csv')
