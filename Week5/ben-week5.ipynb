# %%
import pandas as pd

# %%
songs_df = pd.read_csv('C:/Users/bflem/src/Tamid-TechEdu-S22/Week5/spotify_top_100.csv')
songs_df
# Out:
#                                               title            artist  \
# 0                     STARSTRUKK (feat. Katy Perry)             3OH!3
# 1                       My First Kiss (feat. Ke$ha)             3OH!3
# 2                                   I Need A Dollar        Aloe Blacc
# 3     Airplanes (feat. Hayley Williams of Paramore)             B.o.B
# 4                 Nothin' on You (feat. Bruno Mars)             B.o.B
# ...                                             ...               ...
# 998                     Strike a Pose (feat. Aitch)  Young T & Bugsey
# 999       The London (feat. J. Cole & Travis Scott)        Young Thug
# 1000                                            NaN               NaN
# 1001                                            NaN               NaN
# 1002                                            NaN               NaN
#
#         top genre  year released       added    bpm  nrgy  dnce   dB  live  \
# ...

# %%
songs_df.describe()
# Out:
#        year released          bpm         nrgy         dnce           dB  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     2014.390000   121.262000    69.502000    66.876000    -5.663000
# std         3.241359    26.238022    15.961415    13.121921     2.025224
# min      1975.000000    65.000000     6.000000    19.000000   -18.000000
# 25%      2012.000000   100.000000    59.000000    59.000000    -7.000000
# 50%      2014.000000   122.000000    71.000000    68.000000    -5.000000
# 75%      2017.000000   134.000000    81.250000    75.000000    -4.000000
# max      2021.000000   206.000000    98.000000    96.000000    -1.000000
#
#               live          val          dur       acous         spch  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     17.911000    50.901000   220.406000    14.36900    10.064000
# std      13.431511    21.563399    39.927677    19.45403     9.276743
# ...

# %%
df = songs_df.dropna()
df
# Out:
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 995                                     SICKO MODE        Travis Scott
# 996                                      EARFQUAKE  Tyler, The Creator
# 997                      Boasty (feat. Idris Elba)               Wiley
# 998                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 999      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#        top genre  year released       added    bpm  nrgy  dnce   dB  live  \
# ...

# %%
df2 = df.loc[df['bpm'] > 100]
df2
# Out:
#                                  title            artist    top genre  \
# 0        STARSTRUKK (feat. Katy Perry)             3OH!3    dance pop
# 1          My First Kiss (feat. Ke$ha)             3OH!3    dance pop
# 4    Nothin' on You (feat. Bruno Mars)             B.o.B  atl hip hop
# 6                 The Time (Dirty Bit)   Black Eyed Peas    dance pop
# 8                  Talking to the Moon        Bruno Mars    dance pop
# ..                                 ...               ...          ...
# 991                          Vossi Bop           Stormzy        grime
# 993                       Cruel Summer      Taylor Swift          pop
# 995                         SICKO MODE      Travis Scott      hip hop
# 997          Boasty (feat. Idris Elba)             Wiley        grime
# 998        Strike a Pose (feat. Aitch)  Young T & Bugsey    afroswing
#
#      year released       added    bpm  nrgy  dnce   dB  live   val    dur  \
# ...

# %%
df3 = df2.loc[df2['year released'] > 2015]
df3
# Out:
#                                     title              artist  \
# 68                 This Ain't a Love Song  Scouting For Girls
# 69                           Eenie Meenie       Sean Kingston
# 98           We No Speak Americano (Edit)     Yolanda Be Cool
# 121                      Beautiful People         Chris Brown
# 168  I Follow Rivers - The Magician Remix            Lykke Li
# ..                                    ...                 ...
# 991                             Vossi Bop             Stormzy
# 993                          Cruel Summer        Taylor Swift
# 995                            SICKO MODE        Travis Scott
# 997             Boasty (feat. Idris Elba)               Wiley
# 998           Strike a Pose (feat. Aitch)    Young T & Bugsey
#
#             top genre  year released       added    bpm  nrgy  dnce   dB  \
# 68          dance pop         2017.0  2022‑02‑17  177.0  91.0  46.0 -4.0
# ...

# %%
df4 = df3.loc[df3['artist type'] == 'Solo']
df4
# Out:
#                                     title           artist  top genre  \
# 69                           Eenie Meenie    Sean Kingston  dance pop
# 121                      Beautiful People      Chris Brown  dance pop
# 168  I Follow Rivers - The Magician Remix         Lykke Li    art pop
# 182                     Read All About It  Professor Green      grime
# 366                  Animals - Radio Edit    Martin Garrix  dance pop
# ..                                    ...              ...        ...
# 990                Don’t Feel Like Crying           Sigrid  dance pop
# 991                             Vossi Bop          Stormzy      grime
# 993                          Cruel Summer     Taylor Swift        pop
# 995                            SICKO MODE     Travis Scott    hip hop
# 997             Boasty (feat. Idris Elba)            Wiley      grime
#
#      year released       added    bpm  nrgy  dnce   dB  live   val    dur  \
# ...

# %%
df4.to_csv('spotify_top_100_cleaned.csv')
df5 = df4.loc[:, ['title', 'bpm','nrgy']]
df5
# Out:
#                                     title    bpm  nrgy
# 69                           Eenie Meenie  121.0  64.0
# 121                      Beautiful People  128.0  78.0
# 168  I Follow Rivers - The Magician Remix  122.0  70.0
# 182                     Read All About It  101.0  75.0
# 366                  Animals - Radio Edit  128.0  91.0
# ..                                    ...    ...   ...
# 990                Don’t Feel Like Crying  120.0  81.0
# 991                             Vossi Bop  188.0  65.0
# 993                          Cruel Summer  170.0  70.0
# 995                            SICKO MODE  155.0  73.0
# 997             Boasty (feat. Idris Elba)  103.0  77.0
#
# [230 rows x 3 columns]

# %%
df5.plot()
df5.corr()
# Out:
#            bpm      nrgy
# bpm   1.000000  0.039138
# nrgy  0.039138  1.000000
