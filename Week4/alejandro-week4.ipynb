# %%
# -----------------------------------------------------------
# demonstrates further usage implementation details with 
# python libraries.
#
# NOTE: CSV file provided displays a daily record of the top
#       trending YouTube videos from a variety of regions
#       (Specifically USA)
#           - the data does NOT represent the most-viewed
#             videos overall for the calendar year
#
# 4 April 2022, Alejandro Echaniz
# -----------------------------------------------------------

# import statements for accessing csv files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 2a. printing the dataframe
# printing out the dataset by assigning it to a variable
videos_df = pd.read_csv("ae_dataSet.csv")
videos_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
# Step 2b. access columns + save as variable
videos_df_cols = videos_df.columns.str.replace("_", " ")
videos_df_cols

# setting columns to new variable
videos_df.columns = videos_df_cols

# %%
# step 2c. create a crosstab between 2 columns
byChannel = pd.crosstab(videos_df["views"], videos_df["channel title"])
byChannel
# Out:
# channel title  12 News  1MILLION Dance Studio  1theK (원더케이)  20th Century Fox  \
# views
# 549                  0                      0             0                 0
# 554                  0                      0             0                 0
# 559                  0                      0             0                 0
# 658                  0                      0             0                 0
# 687                  0                      0             0                 0
# ...                ...                    ...           ...               ...
# 205643016            0                      0             0                 0
# 210338856            0                      0             0                 0
# 217750076            0                      0             0                 0
# 220490543            0                      0             0                 0
# 225211923            0                      0             0                 0
#
# ...

# %%
# step 2d. checking data types of each column
videos_df.dtypes
# Out:
# video id                  object
# trending date             object
# title                     object
# channel title             object
# category id                int64
# publish time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment count              int64
# thumbnail link            object
# comments disabled           bool
# ratings disabled            bool
# video error or removed      bool
# description               object
# dtype: object

# %%
# 'cleaner' dataframe to work with
df2 = videos_df[['channel title','title','views', 'likes', 'dislikes', 'comment count']]
df2
# Out:
#                   channel title  \
# 0                  CaseyNeistat
# 1               LastWeekTonight
# 2                  Rudy Mancuso
# 3         Good Mythical Morning
# 4                      nigahiga
# ...                         ...
# 40944             AaronsAnimals
# 40945                  zefrank1
# 40946                Brad Mondo
# 40947  How It Should Have Ended
# 40948              Call of Duty
#
#                                                    title     views   likes  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE    748374   57527
# 1      The Trump Presidency: Last Week Tonight with J...   2418783   97185
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...   3191434  146033
# 3                       Nickelback Lyrics: Real or Fake?    343168   10172
# 4                               I Dare You: GOING BALD!?   2095731  132235
# ...                                                  ...       ...     ...
# ...

# %%
# step 2e. utulizing .loc method
d3 = df2.loc[df2.title.str.contains("Black Panther")]
# Out:
#                   channel title  \
# 6091             ColliderVideos
# 6324             ColliderVideos
# 6550             ColliderVideos
# 6766             ColliderVideos
# 11211      Marvel Entertainment
# ...                         ...
# 37934               Vanity Fair
# 38144               Vanity Fair
# 40540  How It Should Have Ended
# 40741  How It Should Have Ended
# 40947  How It Should Have Ended
#
#                                                    title    views   likes  \
# 6091   Black Panther: New International Trailer Relea...    53703    1795
# 6324   Black Panther: New International Trailer Relea...    56815    1865
# 6550   Black Panther: New International Trailer Relea...    57762    1887
# 6766   Black Panther: New International Trailer Relea...    58643    1908
# 11211       Marvel Studios' Black Panther - Rise TV Spot   216047   14047
# ...                                                  ...      ...     ...
# ...

# %%
# step 2f. converting variable into array
channel_titles = df2['channel title'].head(100)
array = np.asarray(channel_titles)
array[50]
# Out:
# 'Simply Nailogical'

# %%
# step 2g. creating a boxplot with 2 numerical columns
df2.boxplot(column=["dislikes","likes"])
# Out:
# <AxesSubplot:>
